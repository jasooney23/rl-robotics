# %%
import stable_baselines3 as baselines, gymnasium as gym

# %%
env = gym.make("Swimmer-v5")
model = baselines.SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1e6)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 26.3     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 89       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.0395   |
# |    ent_coef        | 0.32     |
# |    ent_coef_loss   | -3.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 27.1     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 88       |
# ...

# %%
model.ent_coef_tensor
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.ent_coef_tensor
#
# AttributeError: 'SAC' object has no attribute 'ent_coef_tensor'

# %%
model.save("sac_swimmer_sb3")

# %%
env.step(action)
# Out:
# (array([ 0.31199872, -0.75106122,  0.71881802, -0.31413966, -2.60851944,
#          2.56930394, -5.6383964 ,  5.65160616]),
#  -0.28995733505234417,
#  False,
#  False,
#  {'x_position': -0.11925466315714076,
#   'y_position': -0.31133652917382126,
#   'distance_from_origin': 0.3333948246189865,
#   'x_velocity': -0.28976252149090465,
#   'y_velocity': -2.688577183433391,
#   'reward_forward': -0.28976252149090465,
#   'reward_ctrl': -0.00019481356143951416})

# %%
env = gym.make("Swimmer-v5", render_mode="human")
while True:
    obs, info = env.reset()
    for _ in range(1000):
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, dones, trunc, info = env.step(action)
        env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 6
#       4 for _ in range(1000):
#       5     action, _states = model.predict(obs, deterministic=True)
# ----> 6     obs, rewards, dones, trunc, info = env.step(action)
#       7     env.render()
#
# File c:\Users\jason\miniforge3\envs\torch\Lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
# ...
